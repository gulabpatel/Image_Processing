# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/Image_Processing/blob/main/Part%201.3%3A%20OpenCV_ColorSpaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Help is available on https://www.youtube.com/watch?v=oXlwWbU8l2o&t=1123s

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img = cv.imread("photo.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F244BA95BA8>

# %% [markdown]
# #BGR to Grayscal

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=180x200 at 0x7F244BA1BDD8>

# %% [markdown]
# #BGR to HSV
#
# (HUE, ATURATION, VALUE)

# %%
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
cv2_imshow(hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F244BA1BE10>

# %% [markdown]
# #BGR to L*a*b

# %%
lab = cv.cvtColor(img, cv.COLOR_BGR2LAB)
cv2_imshow(lab)
# Out:
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F244BA1BEF0>

# %% [markdown]
# #BGR to RGB

# %%
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv2_imshow(rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F244BA1BF28>

# %% [markdown]
# #Split the  image channels

# %%
b,g,r = cv.split(img)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=L size=180x200 at 0x7F244B9AA0F0>
# <PIL.Image.Image image mode=L size=180x200 at 0x7F244B9AA198>
# <PIL.Image.Image image mode=L size=180x200 at 0x7F244B9AA048>

# %% [markdown]
# #Merge B,G,R channels

# %%
merged = cv.merge([b,g,r])
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=180x200 at 0x7F244BA1BEB8>

# %% [markdown]
# -------------------------------
